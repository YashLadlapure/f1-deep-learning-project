# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # LOAD DATA

# %%
circuits = pd.read_csv('dataset/circuits.csv')  #
constructors = pd.read_csv('dataset/constructors.csv') #
constructor_results = pd.read_csv('dataset/constructor_results.csv')
constructor_standings = pd.read_csv('dataset/constructor_standings.csv')
drivers = pd.read_csv('dataset/drivers.csv') #
driver_standings = pd.read_csv('dataset/driver_standings.csv')
lap_times = pd.read_csv('dataset/lap_times.csv') #
pit_stops = pd.read_csv('dataset/pit_stops.csv')  # 
qualifying = pd.read_csv('dataset/qualifying.csv') 
races = pd.read_csv('dataset/races.csv')  #
results = pd.read_csv('dataset/results.csv') #
seasons = pd.read_csv('dataset/seasons.csv')
sprint_results = pd.read_csv('dataset/sprint_results.csv')
status = pd.read_csv('dataset/status.csv')

# %% [markdown]
# # CREATE DF

# %%
lap_times.rename(columns={
    'time': 'lap_time',
    'milliseconds': 'lap_time_ms'
}, inplace=True)
lap_times.drop(columns=['lap_time'], inplace=True)
lap_times
# Out:
#         raceId  driverId  lap  position  lap_time_ms
# 0          841        20    1         1        98109
# 1          841        20    2         1        93006
# 2          841        20    3         1        92713
# 3          841        20    4         1        92803
# 4          841        20    5         1        92342
# ...        ...       ...  ...       ...          ...
# 618761    1171       864   53        13        95123
# 618762    1171       866   53        14        94314
# 618763    1171       832   53        15        94539
# 618764    1171       861   53        16        94685
# 618765    1171       815   53        17        95637
#
# [618766 rows x 5 columns]

# %%
df = lap_times.copy()

# %%
df
# Out:
#         raceId  driverId  lap  position  lap_time_ms
# 0          841        20    1         1        98109
# 1          841        20    2         1        93006
# 2          841        20    3         1        92713
# 3          841        20    4         1        92803
# 4          841        20    5         1        92342
# ...        ...       ...  ...       ...          ...
# 618761    1171       864   53        13        95123
# 618762    1171       866   53        14        94314
# 618763    1171       832   53        15        94539
# 618764    1171       861   53        16        94685
# 618765    1171       815   53        17        95637
#
# [618766 rows x 5 columns]

# %%
races = races.drop(columns=['fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
       'quali_date', 'quali_time', 'sprint_date', 'sprint_time', 'url'])

# %%
races.rename(columns={
    'name': 'race_name',
    'date': 'race_date',
    'time': 'race_time',
    'year': 'race_year'
}, inplace=True)
races = races[races['race_year'] >= 2010]

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 351 entries, 336 to 1170
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   raceId     351 non-null    int64
#  1   race_year  351 non-null    int64
#  2   round      351 non-null    int64
#  3   circuitId  351 non-null    int64
#  4   race_name  351 non-null    object
#  5   race_date  351 non-null    object
#  6   race_time  351 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 21.9+ KB

# %%
df = df.merge(races, on='raceId', how='inner')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372493 entries, 0 to 372492
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   raceId       372493 non-null  int64
#  1   driverId     372493 non-null  int64
#  2   lap          372493 non-null  int64
#  3   position     372493 non-null  int64
#  4   lap_time_ms  372493 non-null  int64
#  5   race_year    372493 non-null  int64
#  6   round        372493 non-null  int64
#  7   circuitId    372493 non-null  int64
#  8   race_name    372493 non-null  object
#  9   race_date    372493 non-null  object
#  10  race_time    372493 non-null  object
# dtypes: int64(8), object(3)
# memory usage: 31.3+ MB

# %%
pit_stops_renamed = pit_stops.rename(columns={'lap': 'pit_lap'})
df = df.merge(
    pit_stops_renamed[['raceId', 'driverId', 'pit_lap']],
    left_on=['raceId', 'driverId', 'lap'],
    right_on=['raceId', 'driverId', 'pit_lap'],
    how='left'
)

# %%
df
# Out:
#         raceId  driverId  lap  position  lap_time_ms  race_year  round  \
# 0          841        20    1         1        98109       2011      1
# 1          841        20    2         1        93006       2011      1
# 2          841        20    3         1        92713       2011      1
# 3          841        20    4         1        92803       2011      1
# 4          841        20    5         1        92342       2011      1
# ...        ...       ...  ...       ...          ...        ...    ...
# 372488    1171       864   53        13        95123       2026      3
# 372489    1171       866   53        14        94314       2026      3
# 372490    1171       832   53        15        94539       2026      3
# 372491    1171       861   53        16        94685       2026      3
# 372492    1171       815   53        17        95637       2026      3
#
#         circuitId              race_name   race_date race_time  pit_lap
# 0               1  Australian Grand Prix  2011-03-27  06:00:00      NaN
# 1               1  Australian Grand Prix  2011-03-27  06:00:00      NaN
# 2               1  Australian Grand Prix  2011-03-27  06:00:00      NaN
# 3               1  Australian Grand Prix  2011-03-27  06:00:00      NaN
# 4               1  Australian Grand Prix  2011-03-27  06:00:00      NaN
# ...           ...                    ...         ...       ...      ...
# 372488         22    Japanese Grand Prix  2026-03-29  05:00:00      NaN
# 372489         22    Japanese Grand Prix  2026-03-29  05:00:00      NaN
# 372490         22    Japanese Grand Prix  2026-03-29  05:00:00      NaN
# 372491         22    Japanese Grand Prix  2026-03-29  05:00:00      NaN
# 372492         22    Japanese Grand Prix  2026-03-29  05:00:00      NaN
#
# [372493 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372493 entries, 0 to 372492
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   raceId       372493 non-null  int64
#  1   driverId     372493 non-null  int64
#  2   lap          372493 non-null  int64
#  3   position     372493 non-null  int64
#  4   lap_time_ms  372493 non-null  int64
#  5   race_year    372493 non-null  int64
#  6   round        372493 non-null  int64
#  7   circuitId    372493 non-null  int64
#  8   race_name    372493 non-null  object
#  9   race_date    372493 non-null  object
#  10  race_time    372493 non-null  object
#  11  pit_lap      12863 non-null   float64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 34.1+ MB

# %%
df['pit_stop'] = df['pit_lap'].notna().astype(int)
df.drop(columns=['pit_lap'], inplace=True)

# %%
df['tyre_age'] = 0
df = df.sort_values(['raceId', 'driverId', 'lap'])
for (race, driver), group in df.groupby(['raceId', 'driverId']):
    last_pit = 0
    ages = []
    
    for lap, pit in zip(group['lap'], group['pit_stop']):
        if pit == 1:
            last_pit = lap
        ages.append(lap - last_pit)
    
    df.loc[group.index, 'tyre_age'] = ages

# %%
df
# Out:
#         raceId  driverId  lap  position  lap_time_ms  race_year  round  \
# 113843     337         1    1         5       128558       2010      1
# 113844     337         1    2         5       123578       2010      1
# 113845     337         1    3         5       123722       2010      1
# 113846     337         1    4         5       123558       2010      1
# 113847     337         1    5         5       123283       2010      1
# ...        ...       ...  ...       ...          ...        ...    ...
# 372410    1171       866   49        14        95229       2026      3
# 372430    1171       866   50        14        94845       2026      3
# 372450    1171       866   51        14        94600       2026      3
# 372470    1171       866   52        14        94585       2026      3
# 372489    1171       866   53        14        94314       2026      3
#
#         circuitId            race_name   race_date race_time  pit_stop  \
# 113843          3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 113844          3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 113845          3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 113846          3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 113847          3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# ...           ...                  ...         ...       ...       ...
# 372410         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372430         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372450         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372470         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372489         22  Japanese Grand Prix  2026-03-29  05:00:00         0
#
#         tyre_age
# 113843         1
# 113844         2
# 113845         3
# 113846         4
# 113847         5
# ...          ...
# 372410        31
# 372430        32
# 372450        33
# 372470        34
# 372489        35
#
# [372493 rows x 13 columns]

# %%
df = df.merge(
    results[['raceId', 'driverId', 'constructorId', 'grid', 'positionOrder']],
    on=['raceId', 'driverId'],
    how='left'
)

# %%
df
# Out:
#         raceId  driverId  lap  position  lap_time_ms  race_year  round  \
# 0          337         1    1         5       128558       2010      1
# 1          337         1    2         5       123578       2010      1
# 2          337         1    3         5       123722       2010      1
# 3          337         1    4         5       123558       2010      1
# 4          337         1    5         5       123283       2010      1
# ...        ...       ...  ...       ...          ...        ...    ...
# 372488    1171       866   49        14        95229       2026      3
# 372489    1171       866   50        14        94845       2026      3
# 372490    1171       866   51        14        94600       2026      3
# 372491    1171       866   52        14        94585       2026      3
# 372492    1171       866   53        14        94314       2026      3
#
#         circuitId            race_name   race_date race_time  pit_stop  \
# 0               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 1               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 2               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 3               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 4               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# ...           ...                  ...         ...       ...       ...
# 372488         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372489         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372490         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372491         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372492         22  Japanese Grand Prix  2026-03-29  05:00:00         0
#
#         tyre_age  constructorId grid  positionOrder
# 0              1              1    4              3
# 1              2              1    4              3
# 2              3              1    4              3
# 3              4              1    4              3
# 4              5              1    4              3
# ...          ...            ...  ...            ...
# 372488        31            215   10             14
# 372489        32            215   10             14
# 372490        33            215   10             14
# 372491        34            215   10             14
# 372492        35            215   10             14
#
# [372493 rows x 16 columns]

# %%
df = df.merge(
    circuits[['circuitId', 'lat', 'lng', 'alt']],
    on='circuitId',
    how='left'
)
df
# Out:
#         raceId  driverId  lap  position  lap_time_ms  race_year  round  \
# 0          337         1    1         5       128558       2010      1
# 1          337         1    2         5       123578       2010      1
# 2          337         1    3         5       123722       2010      1
# 3          337         1    4         5       123558       2010      1
# 4          337         1    5         5       123283       2010      1
# ...        ...       ...  ...       ...          ...        ...    ...
# 372488    1171       866   49        14        95229       2026      3
# 372489    1171       866   50        14        94845       2026      3
# 372490    1171       866   51        14        94600       2026      3
# 372491    1171       866   52        14        94585       2026      3
# 372492    1171       866   53        14        94314       2026      3
#
#         circuitId            race_name   race_date race_time  pit_stop  \
# 0               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 1               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 2               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 3               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 4               3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# ...           ...                  ...         ...       ...       ...
# 372488         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372489         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372490         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372491         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372492         22  Japanese Grand Prix  2026-03-29  05:00:00         0
#
#         tyre_age  constructorId grid  positionOrder      lat       lng  alt
# 0              1              1    4              3  26.0325   50.5106    7
# 1              2              1    4              3  26.0325   50.5106    7
# 2              3              1    4              3  26.0325   50.5106    7
# 3              4              1    4              3  26.0325   50.5106    7
# 4              5              1    4              3  26.0325   50.5106    7
# ...          ...            ...  ...            ...      ...       ...  ...
# 372488        31            215   10             14  34.8431  136.5410   45
# 372489        32            215   10             14  34.8431  136.5410   45
# 372490        33            215   10             14  34.8431  136.5410   45
# 372491        34            215   10             14  34.8431  136.5410   45
# 372492        35            215   10             14  34.8431  136.5410   45
#
# [372493 rows x 19 columns]

# %%
df.to_csv("f1.csv")

# %% [markdown]
# # EDA

# %%
df.isnull().sum()
# Out:
# raceId           0
# driverId         0
# lap              0
# position         0
# lap_time_ms      0
# race_year        0
# round            0
# circuitId        0
# race_name        0
# race_date        0
# race_time        0
# pit_stop         0
# tyre_age         0
# constructorId    0
# grid             0
# positionOrder    0
# lat              0
# lng              0
# alt              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# raceId           0
# driverId         0
# lap              0
# position         0
# lap_time_ms      0
# race_year        0
# round            0
# circuitId        0
# race_name        0
# race_date        0
# race_time        0
# pit_stop         0
# tyre_age         0
# constructorId    0
# grid             0
# positionOrder    0
# lat              0
# lng              0
# alt              0
# dtype: int64

# %%
df.describe()
df['lap_time_ms'].median()
# Out:
# 93507.0

# %%
df.columns
# Out:
# Index(['raceId', 'driverId', 'lap', 'position', 'lap_time_ms', 'race_year',
#        'round', 'circuitId', 'race_name', 'race_date', 'race_time', 'pit_stop',
#        'tyre_age', 'constructorId', 'grid', 'positionOrder', 'lat', 'lng',
#        'alt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372493 entries, 0 to 372492
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   raceId         372493 non-null  int64
#  1   driverId       372493 non-null  int64
#  2   lap            372493 non-null  int64
#  3   position       372493 non-null  int64
#  4   lap_time_ms    372493 non-null  int64
#  5   race_year      372493 non-null  int64
#  6   round          372493 non-null  int64
#  7   circuitId      372493 non-null  int64
#  8   race_name      372493 non-null  object
#  9   race_date      372493 non-null  object
#  10  race_time      372493 non-null  object
#  11  pit_stop       372493 non-null  int64
#  12  tyre_age       372493 non-null  int64
#  13  constructorId  372493 non-null  int64
#  14  grid           372493 non-null  object
#  15  positionOrder  372493 non-null  int64
#  16  lat            372493 non-null  float64
#  17  lng            372493 non-null  float64
#  18  alt            372493 non-null  int64
# dtypes: float64(2), int64(13), object(4)
# memory usage: 54.0+ MB

# %%
numerical_cols = [
    'lap', 'lap_time_ms', 'race_year', 'circuitId', 'pit_stop', 'tyre_age', 
]

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True, bins=20)

# %%
for col in numerical_cols:
    plt.figure(figsize=(10, 8))
    sns.boxplot( x = df[col])

# %%
df = df[df['lap_time_ms'] <= 120000]

# %%
plt.figure(figsize=(10, 8))
sns.boxplot( x = df['lap_time_ms'])
# Out:
# <Axes: xlabel='lap_time_ms'>

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (348196, 19)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (348196, 19)

# %% [markdown]
# # FEATURE ENG AND EXT

# %%
df['grid'] = pd.to_numeric(df['grid'], errors='coerce')
df = df.dropna(subset=['grid'])

# %%
train_df = df[df['race_year'] < 2020]
test_df  = df[df['race_year'] >= 2020]

driver_avg = train_df.groupby('driverId')['lap_time_ms'].mean()

train_df['driver_skill'] = train_df['driverId'].map(driver_avg)
test_df['driver_skill']  = test_df['driverId'].map(driver_avg)

test_df['driver_skill'] = test_df['driver_skill'].fillna(driver_avg.mean())

# %%
circuit_avg = train_df.groupby('circuitId')['lap_time_ms'].mean()

train_df['circuit_difficulty'] = train_df['circuitId'].map(circuit_avg)
test_df['circuit_difficulty']  = test_df['circuitId'].map(circuit_avg)

test_df['circuit_difficulty'] = test_df['circuit_difficulty'].fillna(circuit_avg.mean())
df
# Out:
#         raceId  driverId  lap  position  lap_time_ms  race_year  round  \
# 32         337         1   33         4       119706       2010      1
# 35         337         1   36         4       119904       2010      1
# 40         337         1   41         3       119731       2010      1
# 41         337         1   42         3       119560       2010      1
# 42         337         1   43         3       119590       2010      1
# ...        ...       ...  ...       ...          ...        ...    ...
# 372488    1171       866   49        14        95229       2026      3
# 372489    1171       866   50        14        94845       2026      3
# 372490    1171       866   51        14        94600       2026      3
# 372491    1171       866   52        14        94585       2026      3
# 372492    1171       866   53        14        94314       2026      3
#
#         circuitId            race_name   race_date race_time  pit_stop  \
# 32              3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 35              3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 40              3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 41              3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# 42              3   Bahrain Grand Prix  2010-03-14  12:00:00         0
# ...           ...                  ...         ...       ...       ...
# 372488         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372489         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372490         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372491         22  Japanese Grand Prix  2026-03-29  05:00:00         0
# 372492         22  Japanese Grand Prix  2026-03-29  05:00:00         0
#
#         tyre_age  constructorId  grid  positionOrder      lat       lng  alt
# 32            18              1   4.0              3  26.0325   50.5106    7
# 35            21              1   4.0              3  26.0325   50.5106    7
# 40            26              1   4.0              3  26.0325   50.5106    7
# 41            27              1   4.0              3  26.0325   50.5106    7
# 42            28              1   4.0              3  26.0325   50.5106    7
# ...          ...            ...   ...            ...      ...       ...  ...
# 372488        31            215  10.0             14  34.8431  136.5410   45
# 372489        32            215  10.0             14  34.8431  136.5410   45
# 372490        33            215  10.0             14  34.8431  136.5410   45
# 372491        34            215  10.0             14  34.8431  136.5410   45
# 372492        35            215  10.0             14  34.8431  136.5410   45
#
# [347191 rows x 19 columns]

# %%
train_df['prev_lap_time'] = train_df.groupby(['raceId','driverId'])['lap_time_ms'].shift(1)
test_df['prev_lap_time']  = test_df.groupby(['raceId','driverId'])['lap_time_ms'].shift(1)

train_df = train_df.dropna()
test_df  = test_df.dropna()

# %%
df.columns
# Out:
# Index(['raceId', 'driverId', 'lap', 'position', 'lap_time_ms', 'race_year',
#        'round', 'circuitId', 'race_name', 'race_date', 'race_time', 'pit_stop',
#        'tyre_age', 'constructorId', 'grid', 'positionOrder', 'lat', 'lng',
#        'alt'],
#       dtype='object')

# %%
drop_cols = [
    'race_name', 'race_date', 'race_time', 'raceId', 'drverId', 'circuitId', 'constructorId'
]

# %%
features = [
    'lap',
    'position',
    'pit_stop',
    'tyre_age',
    'grid',
    'alt',
    'driver_skill',
    'circuit_difficulty',
    'race_year',
    'round',
    'prev_lap_time'
]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 347191 entries, 32 to 372492
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   raceId         347191 non-null  int64
#  1   driverId       347191 non-null  int64
#  2   lap            347191 non-null  int64
#  3   position       347191 non-null  int64
#  4   lap_time_ms    347191 non-null  int64
#  5   race_year      347191 non-null  int64
#  6   round          347191 non-null  int64
#  7   circuitId      347191 non-null  int64
#  8   race_name      347191 non-null  object
#  9   race_date      347191 non-null  object
#  10  race_time      347191 non-null  object
#  11  pit_stop       347191 non-null  int64
#  12  tyre_age       347191 non-null  int64
#  13  constructorId  347191 non-null  int64
#  14  grid           347191 non-null  float64
#  15  positionOrder  347191 non-null  int64
#  16  lat            347191 non-null  float64
#  17  lng            347191 non-null  float64
#  18  alt            347191 non-null  int64
# dtypes: float64(3), int64(13), object(3)
# memory usage: 53.0+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X_train = train_df[features]
y_train = train_df['lap_time_ms']

X_test = test_df[features]
y_test = test_df['lap_time_ms']

model = RandomForestRegressor(n_estimators=100, n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

y_pred = model.predict(X_test)

print("R2:", r2_score(y_test, y_pred))
print("MAE (sec):", mean_absolute_error(y_test, y_pred)/1000)
# Out:
# R2: 0.8662170106274487
# MAE (sec): 2.03870326765457

# %%
y_test
# Out:
# 226232    70550
# 226233    70362
# 226234    69340
# 226235    69461
# 226236    69294
#           ...
# 372488    95229
# 372489    94845
# 372490    94600
# 372491    94585
# 372492    94314
# Name: lap_time_ms, Length: 134696, dtype: int64

# %%
y_pred
# Out:
# array([71828.3 , 70754.36, 70678.33, ..., 96085.02, 95228.05, 95391.75],
#       shape=(134696,))

# %% [markdown]
# # KNN

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_absolute_error

knn = KNeighborsRegressor(
    n_neighbors=40,  
    n_jobs=-1
)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1, n_neighbors=40)

# %%
y_pred_knn = knn.predict(X_test_scaled)

r2_knn  = r2_score(y_test, y_pred_knn)
mae_knn = mean_absolute_error(y_test, y_pred_knn)/1000  

print("knn R2:", r2_knn)
print("knn MAE (sec):", mae_knn)
# Out:
# KNN R2: 0.7173532140079664
# KNN MAE (sec): 3.943390041649344

# %% [markdown]
# # LINEAR REGG

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test_scaled)

r2_lr  = r2_score(y_test, y_pred_lr)
mae_lr = mean_absolute_error(y_test, y_pred_lr)/1000  

print("linear regression R2:", r2_lr)
print("linear regression mae (sec):", mae_lr)
# Out:
# Linear Regression R2: 0.7977657794689859
# Linear Regression MAE (sec): 2.9740057732658305
